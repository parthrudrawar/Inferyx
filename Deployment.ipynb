# %%
pip install "C:\Users\rudra\Downloads\inferyx-1.0.0-py3-none-any.whl"
# Out:
# Processing c:\users\rudra\downloads\inferyx-1.0.0-py3-none-any.whl
# ...
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/16.4 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/16.4 MB 2.4 MB/s eta 0:00:07
#    ----- ---------------------------------- 2.1/16.4 MB 3.4 MB/s eta 0:00:05
#    ------- -------------------------------- 3.1/16.4 MB 4.4 MB/s eta 0:00:04
#    -------- ------------------------------- 3.7/16.4 MB 4.0 MB/s eta 0:00:04
#    ---------- ----------------------------- 4.5/16.4 MB 3.8 MB/s eta 0:00:04
#    ------------ --------------------------- 5.0/16.4 MB 3.5 MB/s eta 0:00:04
#    ------------ --------------------------- 5.2/16.4 MB 3.3 MB/s eta 0:00:04
#    -------------- ------------------------- 6.0/16.4 MB 3.2 MB/s eta 0:00:04
#    ---------------- ----------------------- 6.8/16.4 MB 3.3 MB/s eta 0:00:03
# ...

# %%
from zipfile import ZipFile
import pprint

wheel_path = r"C:\Users\rudra\Downloads\inferyx-1.0.0-py3-none-any.whl"
with ZipFile(wheel_path, 'r') as zip_ref:
    file_names = zip_ref.namelist()
    pprint.pprint(file_names)
# Out:
# ['inferyx/__init__.py',
#  'inferyx/__pycache__/__init__.cpython-39.pyc',
#  'inferyx/components/__init__.py',
#  'inferyx/components/admin.py',
#  'inferyx/components/data_preparation.py',
#  'inferyx/components/data_science.py',
#  'inferyx/components/__pycache__/__init__.cpython-39.pyc',
#  'inferyx/components/__pycache__/data_science.cpython-39.pyc',
#  'inferyx/config/__init__.py',
#  'inferyx/config/admin_configurartion.py',
#  'inferyx/config/data_preparation_configuration.py',
#  'inferyx/config/data_science_configuration.py',
#  'inferyx/constants/__init__.py',
#  'inferyx/entity/__init__.py',
#  'inferyx/entity/admin_entity.py',
#  'inferyx/entity/data_preparation_entity.py',
#  'inferyx/entity/data_science_entity.py',
#  'inferyx/utils/__init__.py',
#  'inferyx/utils/collection.py',
#  'inferyx/utils/common.py',
#  'inferyx-1.0.0.dist-info/METADATA',
#  'inferyx-1.0.0.dist-info/WHEEL',
#  'inferyx-1.0.0.dist-info/top_level.txt',
#  'inferyx-1.0.0.dist-info/RECORD']

# %%
import inferyx

# %%
from inferyx.components.data_science import
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from inferyx.components.data_science import Model
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\inferyx\components\data_science.py:6
#       4 from datetime import datetime, timedelta
#       5 from inferyx import  logger
# ----> 6 from inferyx.config.data_science_configuration import ConfigurationManager
#       7 from pathlib import  Path
#       8 from inferyx.utils.collection import  *
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\inferyx\config\data_science_configuration.py:5
#       3 from uuid import uuid1
#       4 from inferyx.utils.collection import *
# ----> 5 from inferyx.utils.common import get_featureAttrMap, get_attribute_by_datapod, get_attribute_by_dataset, \
#       6     get_attribute_by_source
#       9 class ConfigurationManager:
# ...
